# %%
# %%capture
! apt update
! apt install texlive-xetex texlive-fonts-recommended texlive-generic-recommended

# %%
import subprocess
import shlex

# %% [markdown]
# Convert to PDF

# %%
s = subprocess.Popen(shlex.split(
    f'jupyter nbconvert /content/BookReview-Classification-Unsupervised.ipynb --to pdf'
    ), shell = False, stdout = subprocess.PIPE, stderr = subprocess.PIPE)
s.wait()
s.stdout.read()
# Out:
# b''
