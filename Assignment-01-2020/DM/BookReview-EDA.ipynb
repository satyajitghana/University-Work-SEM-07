# %%
! pip install --upgrade pandas-profiling

# %%
import gdown

url = 'https://drive.google.com/uc?id=1UPZiTughL3iDtPwreoUs_SX-LfVktrI3'
output = 'BX-CSV-Dump.zip'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UPZiTughL3iDtPwreoUs_SX-LfVktrI3
# To: /content/BX-CSV-Dump.zip
# 26.1MB [00:00, 66.8MB/s]
# 'BX-CSV-Dump.zip'

# %%
! unzip BX-CSV-Dump.zip
# Out:
# Archive:  BX-CSV-Dump.zip
#   inflating: BX-Book-Ratings.csv
#   inflating: BX-Books.csv
#   inflating: BX-Users.csv

# %% [markdown]
# # Book Crossing EDA

# %%
import pandas_profiling
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set()

# %% [markdown]
# Reading the csv files

# %%
users = pd.read_csv(
    '/content/BX-Users.csv', 
    names=['user_id', 'location', 'age'], 
    sep=';',
    skiprows=1,
    encoding='ISO-8859-1', 
    low_memory=False, 
    error_bad_lines=False
)
users
# Out:
#         user_id                            location   age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
books = pd.read_csv(
    '/content/BX-Books.csv',
    names=['isbn', 'book_title', 'book_author', 'year_of_publication', 'publisher', 'img_s', 'img_m', 'img_l'], 
    sep=';',
    skiprows=1,
    encoding='ISO-8859-1', 
    low_memory=False, 
    error_bad_lines=False
)
books
# Out:
#               isbn  ...                                              img_l
# 0       0195153448  ...  http://images.amazon.com/images/P/0195153448.0...
# 1       0002005018  ...  http://images.amazon.com/images/P/0002005018.0...
# 2       0060973129  ...  http://images.amazon.com/images/P/0060973129.0...
# 3       0374157065  ...  http://images.amazon.com/images/P/0374157065.0...
# 4       0393045218  ...  http://images.amazon.com/images/P/0393045218.0...
# ...            ...  ...                                                ...
# 271374  0440400988  ...  http://images.amazon.com/images/P/0440400988.0...
# 271375  0525447644  ...  http://images.amazon.com/images/P/0525447644.0...
# 271376  006008667X  ...  http://images.amazon.com/images/P/006008667X.0...
# 271377  0192126040  ...  http://images.amazon.com/images/P/0192126040.0...
# 271378  0767409752  ...  http://images.amazon.com/images/P/0767409752.0...
#
# [271379 rows x 8 columns]

# %%
ratings = pd.read_csv(
    '/content/BX-Book-Ratings.csv',
    names=['user_id', 'isbn', 'book_rating'],
    sep=';',
    skiprows=1,
    encoding='ISO-8859-1', 
    low_memory=False, 
    error_bad_lines=False
)
ratings
# Out:
#          user_id         isbn  book_rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %% [markdown]
# Join the three datasets based on `user_id` and `isbn`

# %%
temp = pd.merge(users, ratings, on='user_id')
temp = pd.merge(temp, books, on='isbn')
dataset = temp.copy()

# %%
dataset
# Out:
#          user_id  ...                                              img_l
# 0              2  ...  http://images.amazon.com/images/P/0195153448.0...
# 1              8  ...  http://images.amazon.com/images/P/0002005018.0...
# 2          11400  ...  http://images.amazon.com/images/P/0002005018.0...
# 3          11676  ...  http://images.amazon.com/images/P/0002005018.0...
# 4          41385  ...  http://images.amazon.com/images/P/0002005018.0...
# ...          ...  ...                                                ...
# 1031170   278851  ...  http://images.amazon.com/images/P/0743203763.0...
# 1031171   278851  ...  http://images.amazon.com/images/P/0767907566.0...
# 1031172   278851  ...  http://images.amazon.com/images/P/0884159221.0...
# 1031173   278851  ...  http://images.amazon.com/images/P/0912333022.0...
# 1031174   278851  ...  http://images.amazon.com/images/P/1569661057.0...
#
# [1031175 rows x 12 columns]

# %%
dataset = dataset.drop(['img_s', 'img_m', 'img_l'], axis=1)
dataset
# Out:
#          user_id  ...                 publisher
# 0              2  ...   Oxford University Press
# 1              8  ...     HarperFlamingo Canada
# 2          11400  ...     HarperFlamingo Canada
# 3          11676  ...     HarperFlamingo Canada
# 4          41385  ...     HarperFlamingo Canada
# ...          ...  ...                       ...
# 1031170   278851  ...      Simon &amp; Schuster
# 1031171   278851  ...            Broadway Books
# 1031172   278851  ...           Lone Star Books
# 1031173   278851  ...                Kqed Books
# 1031174   278851  ...  American Map Corporation
#
# [1031175 rows x 9 columns]

# %%
# profile = pandas_profiling.ProfileReport(dataset)
# profile
